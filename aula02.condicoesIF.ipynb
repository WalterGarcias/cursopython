# %% [markdown]
# ## Exemplos:
#
# ### Vamos criar um programa para analisar o nônus dos funcionários de uma empresa pode parecer "simples", mas uma empresa como a Amazon tem 900.000 funcionários).
#
# Para os cargos de vendedores, a regra do bônus é de acordo com a meta de vendas da pessoa:
#
# Se ela vendeu abaixo da meta dela, ela não ganha bônus.
#
# Se ela vendeu acima da meta dela, ela ganha como bônus 3% do valor que ela vendeu.
#
# Se ela vendeu mais do que o dobro da meta dela, ela ganha como bônus 7% do valor que ela vendeu.
#
# Vamos criar um programa para valiar uma pessoa que tinha como meta de vendas 20.000 reais e calular o bônus dela de acordo com o valor de vendas que ela tiver.

# %%
meta = 20000
vendas = 30000

if vendas < meta:
    print(f'Você não vai ganhar nada miserave, porque só vendeu {vendas} e não bateu a meta')
elif vendas > (meta * 2):
    print(f'Parabéns cabra da peste, você vendeu {vendas} e consegui atingir a bonificação máxima')
else:
    print(f'Ora, ora parece que você conseguiu uma gordurinha em, vendeu {vendas} e conseguiu 3% de bonificação')
# Out:
# Ora, ora parece que você conseguiu uma gordurinha em, vendeu 30000 e conseguiu 3% de bonificação

# %% [markdown]
# ## Aula 07 - condicionais
#
# ### Exemplo 1: Digamos que você está consturindo um sistema de controle de vnedas de precisa de algumas informações para faazer o cálculo do resultado da loja no fim de um mês.

# %%
faturamento = input('Qual o faturamento da loja nesse mês?')
custo = input('Qual o custo da loja nesse mês?')

if (faturamento == '' or custo == ''):
    print('Verifique se os valores de faturamento e de custo foram preenchidos corretamente')
else: 
    lucro = int(faturamento) - int(custo)
    print('O lucro total da loja foi de {}' .format(lucro))
# Out:
# O lucro total da loja foi de 900

# %% [markdown]
# ## Aula 7 ### Criando um mini sistema de controle de estoque
#
# ### crie um sistema para ser usado pelo time de controle de estoque de um centro de distribiição. Imagine que ao fim de todo dia, o time conta quantas unidades de proto existem no estoque. Se tivermos um estoque abaixo do estoque permitido para aquela categoria do produto. O time deve ser avisado (print), para fazer um novo pedido daquele produto.
#
# Cada categoria de produto tem um estoque mínimo diferente, segundo a regra abaixo:
# - Alimentos- > Estoque mínimo: 50
# - Bebidas -> Estoque mínimo: 75
# - Limpeza -: Estoque mínimo: 30
#
# Para isso, vamos criar um programa que pede 3 inputs do usuário: Nome do protudo, categoria e quanitdade autal em estoque.
# Se o produto tiver abaixo do estoque minímo da categoria dele, o programa deve printar a mensagem "Solicitar {produito}, á equipe de compras, temos apenas {unidades} em estoque.
#
# Exemplo: Se o usuário preenche os inputs com: bebida, dolly, 90, o programa não deve exibir nenhuma mensagem. Agora, se o usuário preenche os inputs com: bebidas, guaraná, 60, o programa deve exibir a mensagem "solicitar guaraná á equipe de compras, emos apenas 60 unidades em estoque.
#
# Obs: Lembre de usar o int() para transformar o número inserido pelo usuário no input de string para int. Obs2: Caso o usuário nõa preencha alguma das 3 informações, o programa deve exibir
# uma mensagem para avisá-lo de preencher corretamnete.

# %%
nome_produto = input('Digite o nome do produto a ser inserido')
categoria = input('Digite o nome da categoria do produto')
quantidade = int(input('Digite a quantidade do produto'))

if quantidade == '' or nome_produto == '' or categoria == '':
    print('Verifique se todos os valores foram digitados corretamente.')
else:
    if categoria == 'alimentos' and quantidade < 50:
        print('Solicitar uma nova remessa de {}, porque a quanitdade atual está baixa, estamos apenas com {}' .format(nome_produto, quantidade))

    elif categoria == 'bebidas' and quantidade < 75:
        print('Solicitar uma nova remessa de {}, porque a quanitdade atual está baixa, estamos apenas com {}' .format(nome_produto, quantidade))
        
    elif categoria == 'limpeza' and quantidade < 30:
            print('Solicitar uma nova remessa de {}, porque a quanitdade atual está baixa, estamos apenas com {}' .format(nome_produto, quantidade))
    else: 
        print('O estoque está ok meu chapa, não tem o que se preocupar')
# Out:
# Solicitar uma nova remessa de Arroz feijó, porque a quanitdade atual está baixa, estamos apenas com 12
